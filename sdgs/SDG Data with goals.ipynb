# %%
import pandas as pd
#### Goal 1
goal1= pd.read_csv('F:/Pykih/SDG Data/Goal 1.csv')

# %%
goal1.head()
# Out:
#           States_Uts  Population living below National Poverty line (%)  \
# 0             Target                                              10.95
# 1              India                                              21.92
# 2      A & N Islands                                               1.00
# 3     Andhra Pradesh                                               9.20
# 4  Arunachal Pradesh                                              34.67
#
#    Households with any usual member covered by any health scheme or health insurance (%)  \
# 0                                              100.0
# 1                                               28.7
# 2                                                5.7
# 3                                               74.6
# 4                                               58.3
#
#    Persons provided employment as a percentage of persons who demanded employment under MGNREGA (%)  \
# 0                                             100.00
# ...

# %%
goal1.shape
# Out:
# (38, 6)

# %%
goal1.insert(1, 'SDG', 1, allow_duplicates=False)

# %%
goal1.head()
# Out:
#           States_Uts  SDG  Population living below National Poverty line (%)  \
# 0             Target    1                                              10.95
# 1              India    1                                              21.92
# 2      A & N Islands    1                                               1.00
# 3     Andhra Pradesh    1                                               9.20
# 4  Arunachal Pradesh    1                                              34.67
#
#    Households with any usual member covered by any health scheme or health insurance (%)  \
# 0                                              100.0
# 1                                               28.7
# 2                                                5.7
# 3                                               74.6
# 4                                               58.3
#
#    Persons provided employment as a percentage of persons who demanded employment under MGNREGA (%)  \
# ...

# %%
goal1.shape
# Out:
# (38, 7)

# %%
### Goal 2
goal2 = pd.read_csv('F:/Pykih/SDG Data/Goal 2.csv')

# %%
goal2.head()
# Out:
#           States_Uts  \
# 0             Target
# 1              India
# 2      A & N Islands
# 3     Andhra Pradesh
# 4  Arunachal Pradesh
#
#    Ratio of rural households covered under public distribution system to rural households where monthly income of highest earning member is less than Rs.5,000  \
# 0                                               1.29
# 1                                               1.01
# 2                                               0.49
# 3                                               0.77
# 4                                               0.92
#
#    Children under age 5 years who are stunted (%)  \
# 0                                           21.03
# 1                                           38.40
# 2                                           23.30
# 3                                           31.40
# 4                                           29.40
#
#    Pregnant women aged 15-49 yrs who are anaemic (11.0g/dl) (%)  \
# ...

# %%
goal2.shape
# Out:
# (38, 5)

# %%
goal2.insert(1, 'SDG', 2, allow_duplicates=False)

# %%
goal2.head()
# Out:
#           States_Uts  SDG  \
# 0             Target    2
# 1              India    2
# 2      A & N Islands    2
# 3     Andhra Pradesh    2
# 4  Arunachal Pradesh    2
#
#    Ratio of rural households covered under public distribution system to rural households where monthly income of highest earning member is less than Rs.5,000  \
# 0                                               1.29
# 1                                               1.01
# 2                                               0.49
# 3                                               0.77
# 4                                               0.92
#
#    Children under age 5 years who are stunted (%)  \
# 0                                           21.03
# 1                                           38.40
# 2                                           23.30
# 3                                           31.40
# 4                                           29.40
#
#    Pregnant women aged 15-49 yrs who are anaemic (11.0g/dl) (%)  \
# ...

# %%
## Goal1 + Goal2
goal12 = goal1.append(goal2, sort=False)

# %%
goal12.head(100)
# Out:
#            States_Uts  SDG  Population living below National Poverty line (%)  \
# 0              Target    1                                              10.95
# 1               India    1                                              21.92
# 2       A & N Islands    1                                               1.00
# 3      Andhra Pradesh    1                                               9.20
# 4   Arunachal Pradesh    1                                              34.67
# 5               Assam    1                                              31.98
# 6               Bihar    1                                              33.74
# 7          Chandigarh    1                                              21.81
# 8        Chhattisgarh    1                                              39.93
# 9        D & N Haveli    1                                              39.31
# 10      Daman and Diu    1                                               9.86
# ...

# %%
# Goal 3
goal3 = pd.read_csv('F:/Pykih/SDG Data/Goal 3.csv')

# %%
goal3.head()
# Out:
#           States_Uts  Maternal Mortality Ratio  \
# 0             Target                      70.0
# 1              India                     130.0
# 2      A & N Islands                       NaN
# 3     Andhra Pradesh                      74.0
# 4  Arunachal Pradesh                       NaN
#
#    Under-five mortality rate per 1,000 live births  \
# 0                                             11.0
# 1                                             50.0
# 2                                             13.0
# 3                                             41.0
# 4                                             33.0
#
#    Children aged 12-23 months fully immunized (BCG, Measles and three doses of Pentavalent vaccine) (%)  \
# 0                                              100.0
# 1                                               62.0
# 2                                               73.2
# 3                                               65.3
# ...

# %%
goal3.shape
# Out:
# (38, 6)

# %%
goal3.insert(1, 'SDG', 3, allow_duplicates=False)

# %%
goal3.head()
# Out:
#           States_Uts  SDG  Maternal Mortality Ratio  \
# 0             Target    3                      70.0
# 1              India    3                     130.0
# 2      A & N Islands    3                       NaN
# 3     Andhra Pradesh    3                      74.0
# 4  Arunachal Pradesh    3                       NaN
#
#    Under-five mortality rate per 1,000 live births  \
# 0                                             11.0
# 1                                             50.0
# 2                                             13.0
# 3                                             41.0
# 4                                             33.0
#
#    Children aged 12-23 months fully immunized (BCG, Measles and three doses of Pentavalent vaccine) (%)  \
# 0                                              100.0
# 1                                               62.0
# 2                                               73.2
# 3                                               65.3
# ...

# %%
goal3.shape
# Out:
# (38, 7)

# %%
## Goal1 + Goal2 + Goal3
goal123 = goal12.append(goal3, sort=False)

# %%
goal123.head(100)
# Out:
#            States_Uts  SDG  Population living below National Poverty line (%)  \
# 0              Target    1                                              10.95
# 1               India    1                                              21.92
# 2       A & N Islands    1                                               1.00
# 3      Andhra Pradesh    1                                               9.20
# 4   Arunachal Pradesh    1                                              34.67
# 5               Assam    1                                              31.98
# 6               Bihar    1                                              33.74
# 7          Chandigarh    1                                              21.81
# 8        Chhattisgarh    1                                              39.93
# 9        D & N Haveli    1                                              39.31
# 10      Daman and Diu    1                                               9.86
# ...

# %%
goal123.shape
# Out:
# (114, 16)

# %%
## Goal4
goal4= pd.read_csv('F:/Pykih/SDG Data/Goal 4.csv')

# %%
goal4.head()
# Out:
#           States_Uts  \
# 0             Target
# 1              India
# 2      A & N Islands
# 3     Andhra Pradesh
# 4  Arunachal Pradesh
#
#    Adjusted Net Enrolment Ratio at Elementary  (Class 1-8) and Secondary (Class 9-10) school (%)  \
# 0                                             100.00
# 1                                              75.83
# 2                                              77.48
# 3                                              63.49
# 4                                              79.02
#
#    Correct responses on Learning Outcomes in Language, Mathematics and EVS for Class 5 students (%)  \
# 0                                              67.89
# 1                                              54.69
# 2                                              52.00
# 3                                              65.00
# 4                                              41.67
#
# ...

# %%
goal4.shape
# Out:
# (38, 8)

# %%
goal4.insert(1, 'SDG', 4, allow_duplicates=False)

# %%
goal4.head()
# Out:
#           States_Uts  SDG  \
# 0             Target    4
# 1              India    4
# 2      A & N Islands    4
# 3     Andhra Pradesh    4
# 4  Arunachal Pradesh    4
#
#    Adjusted Net Enrolment Ratio at Elementary  (Class 1-8) and Secondary (Class 9-10) school (%)  \
# 0                                             100.00
# 1                                              75.83
# 2                                              77.48
# 3                                              63.49
# 4                                              79.02
#
#    Correct responses on Learning Outcomes in Language, Mathematics and EVS for Class 5 students (%)  \
# 0                                              67.89
# 1                                              54.69
# 2                                              52.00
# 3                                              65.00
# 4                                              41.67
#
# ...

# %%
## Goal1 + Goal2 + Goal3 + Goal4
goal1234 = goal123.append(goal4, sort=False)

# %%
goal1234.shape
# Out:
# (152, 23)

# %%
# Goal5
goal5 = pd.read_csv('F:/Pykih/SDG Data/Goal 5.csv')

# %%
goal5.head()
# Out:
#           States_Uts  Sex  Ratio at Birth (female per 1000 male)  \
# 0             Target                                       954.0
# 1              India                                       898.0
# 2      A & N Islands                                         NaN
# 3     Andhra Pradesh                                       913.0
# 4  Arunachal Pradesh                                         NaN
#
#    Average female to male ratio of average wages/salaries received per day by regular wage/salaried employees of age 15-59 for rural and urban  \
# 0                                               1.00
# 1                                               0.70
# 2                                               1.00
# 3                                               0.73
# 4                                               0.80
#
#    Married women aged 15-49 who have ever experienced spousal violence (%)  \
# 0                                                0.0
# ...

# %%
goal5.shape
# Out:
# (38, 7)

# %%
goal5.insert(1, 'SDG', 5, allow_duplicates=False)

# %%
goal5.head()
# Out:
#           States_Uts  SDG  Sex  Ratio at Birth (female per 1000 male)  \
# 0             Target    5                                       954.0
# 1              India    5                                       898.0
# 2      A & N Islands    5                                         NaN
# 3     Andhra Pradesh    5                                       913.0
# 4  Arunachal Pradesh    5                                         NaN
#
#    Average female to male ratio of average wages/salaries received per day by regular wage/salaried employees of age 15-59 for rural and urban  \
# 0                                               1.00
# 1                                               0.70
# 2                                               1.00
# 3                                               0.73
# 4                                               0.80
#
#    Married women aged 15-49 who have ever experienced spousal violence (%)  \
# 0                                                0.0
# ...

# %%
goal5.shape
# Out:
# (38, 8)

# %%
# Goal1 + Goal2 + Goal3 + Goal4 + Goal5
goal12345 = goal1234.append(goal5, sort=False)

# %%
goal12345.head()
# Out:
#           States_Uts  SDG  Population living below National Poverty line (%)  \
# 0             Target    1                                              10.95
# 1              India    1                                              21.92
# 2      A & N Islands    1                                               1.00
# 3     Andhra Pradesh    1                                               9.20
# 4  Arunachal Pradesh    1                                              34.67
#
#    Households with any usual member covered by any health scheme or health insurance (%)  \
# 0                                              100.0
# 1                                               28.7
# 2                                                5.7
# 3                                               74.6
# 4                                               58.3
#
#    Persons provided employment as a percentage of persons who demanded employment under MGNREGA (%)  \
# ...

# %%
goal12345.shape
# Out:
# (190, 29)

# %%
# Goal6
goal6 = pd.read_csv('F:/Pykih/SDG Data/Goal 6.csv')

# %%
goal6.head()
# Out:
#           States_Uts  \
# 0             Target
# 1              India
# 2      A & N Islands
# 3     Andhra Pradesh
# 4  Arunachal Pradesh
#
#    Population having safe and adequate drinking water in rural areas (%)  \
# 0                                             100.00
# 1                                              71.80
# 2                                              88.70
# 3                                              62.84
# 4                                              43.18
#
#    Rural households with individual household toilets (%)  \
# 0                                             100.00
# 1                                              82.72
# 2                                             100.00
# 3                                              99.21
# 4                                             100.00
#
#    Districts verified to be Open Defecation Free (%)  \
# 0                                             100.00
# ...

# %%
goal6.shape
# Out:
# (38, 6)

# %%
goal6.insert(1, 'SDG', 6, allow_duplicates=False)

# %%
goal6.head()
# Out:
#           States_Uts  SDG  \
# 0             Target    6
# 1              India    6
# 2      A & N Islands    6
# 3     Andhra Pradesh    6
# 4  Arunachal Pradesh    6
#
#    Population having safe and adequate drinking water in rural areas (%)  \
# 0                                             100.00
# 1                                              71.80
# 2                                              88.70
# 3                                              62.84
# 4                                              43.18
#
#    Rural households with individual household toilets (%)  \
# 0                                             100.00
# 1                                              82.72
# 2                                             100.00
# 3                                              99.21
# 4                                             100.00
#
#    Districts verified to be Open Defecation Free (%)  \
# 0                                             100.00
# ...

# %%
goal6.shape
# Out:
# (38, 7)

# %%
# Goal1 + Goal2 + Goal3 + Goal4 + Goal5 + Goal6
goal123456 = goal12345.append(goal6, sort=False)

# %%
goal123456.head()
# Out:
#           States_Uts  SDG  Population living below National Poverty line (%)  \
# 0             Target    1                                              10.95
# 1              India    1                                              21.92
# 2      A & N Islands    1                                               1.00
# 3     Andhra Pradesh    1                                               9.20
# 4  Arunachal Pradesh    1                                              34.67
#
#    Households with any usual member covered by any health scheme or health insurance (%)  \
# 0                                              100.0
# 1                                               28.7
# 2                                                5.7
# 3                                               74.6
# 4                                               58.3
#
#    Persons provided employment as a percentage of persons who demanded employment under MGNREGA (%)  \
# ...

# %%
goal123456.shape
# Out:
# (228, 34)

# %%
# Goal7
goal7 = pd.read_csv('F:/Pykih/SDG Data/Goal 7.csv')

# %%
goal7.head()
# Out:
#           States_Uts  Households electrified (%)  \
# 0             Target                      100.00
# 1              India                       94.57
# 2      A & N Islands                         NaN
# 3     Andhra Pradesh                       99.99
# 4  Arunachal Pradesh                       75.78
#
#    Households using Clean Cooking Fuel (%)  \
# 0                                    100.0
# 1                                     43.8
# 2                                     63.5
# 3                                     62.0
# 4                                     45.0
#
#    Renewable share of installed generating capacity (%)
# 0                                              40.00
# 1                                              17.51
# 2                                              22.77
# 3                                              30.17
# 4                                             100.00

# %%
goal7.shape
# Out:
# (38, 4)

# %%
goal7.insert(1, 'SDG', 7, allow_duplicates=False)

# %%
goal7.head()
# Out:
#           States_Uts  SDG  Households electrified (%)  \
# 0             Target    7                      100.00
# 1              India    7                       94.57
# 2      A & N Islands    7                         NaN
# 3     Andhra Pradesh    7                       99.99
# 4  Arunachal Pradesh    7                       75.78
#
#    Households using Clean Cooking Fuel (%)  \
# 0                                    100.0
# 1                                     43.8
# 2                                     63.5
# 3                                     62.0
# 4                                     45.0
#
#    Renewable share of installed generating capacity (%)
# 0                                              40.00
# 1                                              17.51
# 2                                              22.77
# 3                                              30.17
# 4                                             100.00

# %%
goal7.shape
# Out:
# (38, 5)

# %%
# Goal1 + Goal2 + Goal3 + Goal4 + Goal5 + Goal6 + Goal7
goal1_7 = goal123456.append(goal7, sort=False)

# %%
goal1_7.head()
# Out:
#           States_Uts  SDG  Population living below National Poverty line (%)  \
# 0             Target    1                                              10.95
# 1              India    1                                              21.92
# 2      A & N Islands    1                                               1.00
# 3     Andhra Pradesh    1                                               9.20
# 4  Arunachal Pradesh    1                                              34.67
#
#    Households with any usual member covered by any health scheme or health insurance (%)  \
# 0                                              100.0
# 1                                               28.7
# 2                                                5.7
# 3                                               74.6
# 4                                               58.3
#
#    Persons provided employment as a percentage of persons who demanded employment under MGNREGA (%)  \
# ...

# %%
goal1_7.shape
# Out:
# (266, 37)

# %%
# Goal8
goal8 = pd.read_csv('F:/Pykih/SDG Data/Goal 8.csv')

# %%
goal8.head()
# Out:
#           States_Uts  \
# 0             Target
# 1              India
# 2      A & N Islands
# 3     Andhra Pradesh
# 4  Arunachal Pradesh
#
#    Annual growth rate of GDP per capita (at constant price of 2011-12)  \
# 0                                              10.00
# 1                                               6.50
# 2                                               7.06
# 3                                              10.35
# 4                                              13.29
#
#    Average unemployment rate per 1000 persons for males and females  \
# 0                                              14.83
# 1                                              63.50
# 2                                             189.50
# 3                                              39.50
# 4                                              94.00
#
#    Households with a bank account (%)  Number of ATMs per 1,00,000 population
# ...

# %%
goal8.shape
# Out:
# (38, 5)

# %%
goal8.insert(1, 'SDG', 8, allow_duplicates=False)

# %%
goal8.head()
# Out:
#           States_Uts  SDG  \
# 0             Target    8
# 1              India    8
# 2      A & N Islands    8
# 3     Andhra Pradesh    8
# 4  Arunachal Pradesh    8
#
#    Annual growth rate of GDP per capita (at constant price of 2011-12)  \
# 0                                              10.00
# 1                                               6.50
# 2                                               7.06
# 3                                              10.35
# 4                                              13.29
#
#    Average unemployment rate per 1000 persons for males and females  \
# 0                                              14.83
# 1                                              63.50
# 2                                             189.50
# 3                                              39.50
# 4                                              94.00
#
#    Households with a bank account (%)  Number of ATMs per 1,00,000 population
# ...

# %%
# Goal1 + Goal2 + Goal3 + Goal4 + Goal5 + Goal6 + Goal7 + Goal8
goal1_8 = goal1_7.append(goal8, sort=False)

# %%
goal1_8.head()
# Out:
#           States_Uts  SDG  Population living below National Poverty line (%)  \
# 0             Target    1                                              10.95
# 1              India    1                                              21.92
# 2      A & N Islands    1                                               1.00
# 3     Andhra Pradesh    1                                               9.20
# 4  Arunachal Pradesh    1                                              34.67
#
#    Households with any usual member covered by any health scheme or health insurance (%)  \
# 0                                              100.0
# 1                                               28.7
# 2                                                5.7
# 3                                               74.6
# 4                                               58.3
#
#    Persons provided employment as a percentage of persons who demanded employment under MGNREGA (%)  \
# ...

# %%
goal1_8.shape
# Out:
# (304, 41)

# %%
# Goal9
goal9 = pd.read_csv('F:/Pykih/SDG Data/Goal 9.csv')

# %%
goal9.head()
# Out:
#           States_Uts  \
# 0             Target
# 1              India
# 2      A & N Islands
# 3     Andhra Pradesh
# 4  Arunachal Pradesh
#
#    Targeted habitations  connected by all-weather roads under Pradhan Mantri Gram Sadak Yojana (%)  \
# 0                                             100.00
# 1                                              47.38
# 2                                                NaN
# 3                                              18.00
# 4                                              32.00
#
#    Number of mobile connections per 100 persons in rural and urban area (Mobile Tele density)  \
# 0                                             100.00
# 1                                              82.97
# 2                                                NaN
# 3                                              90.92
# 4                                                NaN
#
#    Number of Internet Subscribers per 100 population  \
# ...

# %%
goal9.shape
# Out:
# (38, 5)

# %%
goal9.insert(1, 'SDG', 9, allow_duplicates=False)

# %%
goal9.head()
# Out:
#           States_Uts  SDG  \
# 0             Target    9
# 1              India    9
# 2      A & N Islands    9
# 3     Andhra Pradesh    9
# 4  Arunachal Pradesh    9
#
#    Targeted habitations  connected by all-weather roads under Pradhan Mantri Gram Sadak Yojana (%)  \
# 0                                             100.00
# 1                                              47.38
# 2                                                NaN
# 3                                              18.00
# 4                                              32.00
#
#    Number of mobile connections per 100 persons in rural and urban area (Mobile Tele density)  \
# 0                                             100.00
# 1                                              82.97
# 2                                                NaN
# 3                                              90.92
# 4                                                NaN
#
#    Number of Internet Subscribers per 100 population  \
# ...

# %%
goal9.shape
# Out:
# (38, 6)

# %%
# Goal1 + Goal2 + Goal3 + Goal4 + Goal5 + Goal6 + Goal7 + Goal8 + Goal9
goal1_9 = goal1_8.append(goal9, sort=False)

# %%
goal1_9.shape
# Out:
# (342, 45)

# %%
# Goal10
goal10 = pd.read_csv('F:/Pykih/SDG Data/Goal 10.csv')

# %%
goal10.head()
# Out:
#           States_Uts  Palma Ratio of Household Expenditure in Urban India  \
# 0             Target                                               1.00
# 1              India                                               1.41
# 2      A & N Islands                                               1.76
# 3     Andhra Pradesh                                               1.06
# 4  Arunachal Pradesh                                               1.49
#
#    Palma Ratio of Household Expenditure in Rural India  \
# 0                                               1.00
# 1                                               0.92
# 2                                               0.98
# 3                                               0.73
# 4                                               1.34
#
#    Ratio of Transgender Labour force participation rate to Male Labour force participation rate  \
# 0                                               1.00
# 1                                               0.64
# ...

# %%
goal10.shape
# Out:
# (38, 6)

# %%
goal10.insert(1, 'SDG', 10, allow_duplicates=False)

# %%
goal10.shape
# Out:
# (38, 7)

# %%
goal10.head()
# Out:
#           States_Uts  SDG  \
# 0             Target   10
# 1              India   10
# 2      A & N Islands   10
# 3     Andhra Pradesh   10
# 4  Arunachal Pradesh   10
#
#    Palma Ratio of Household Expenditure in Urban India  \
# 0                                               1.00
# 1                                               1.41
# 2                                               1.76
# 3                                               1.06
# 4                                               1.49
#
#    Palma Ratio of Household Expenditure in Rural India  \
# 0                                               1.00
# 1                                               0.92
# 2                                               0.98
# 3                                               0.73
# 4                                               1.34
#
#    Ratio of Transgender Labour force participation rate to Male Labour force participation rate  \
# ...

# %%
# Goal1 + Goal2 + Goal3 + Goal4 + Goal5 + Goal6 + Goal7 + Goal8 + Goal9 + Goal10
goal1_10 = goal1_9.append(goal10, sort=False)

# %%
goal1_10.head()
# Out:
#           States_Uts  SDG  Population living below National Poverty line (%)  \
# 0             Target    1                                              10.95
# 1              India    1                                              21.92
# 2      A & N Islands    1                                               1.00
# 3     Andhra Pradesh    1                                               9.20
# 4  Arunachal Pradesh    1                                              34.67
#
#    Households with any usual member covered by any health scheme or health insurance (%)  \
# 0                                              100.0
# 1                                               28.7
# 2                                                5.7
# 3                                               74.6
# 4                                               58.3
#
#    Persons provided employment as a percentage of persons who demanded employment under MGNREGA (%)  \
# ...

# %%
goal1_10.shape
# Out:
# (380, 50)

# %%
# Goal11
goal11 = pd.read_csv('F:/Pykih/SDG Data/Goal 11.csv')

# %%
goal11.head()
# Out:
#           States_Uts  \
# 0             Target
# 1              India
# 2      A & N Islands
# 3     Andhra Pradesh
# 4  Arunachal Pradesh
#
#    Houses completed under PMAY as a percentage of net demand assessment for houses  \
# 0                                             100.00
# 1                                               3.32
# 2                                                NaN
# 3                                               2.48
# 4                                               0.17
#
#    Urban households living in slums (%)  \
# 0                                  0.00
# 1                                  5.41
# 2                                  3.72
# 3                                 12.04
# 4                                  1.12
#
#    Wards with 100% door to door waste collection (%)  Waste processed (%)
# 0                                             100.00                100.0
# 1                                              73.58                 24.8
# ...

# %%
goal11.shape
# Out:
# (38, 5)

# %%
goal11.insert(1, 'SDG', 11, allow_duplicates=False)

# %%
goal11.head()
# Out:
#           States_Uts  SDG  \
# 0             Target   11
# 1              India   11
# 2      A & N Islands   11
# 3     Andhra Pradesh   11
# 4  Arunachal Pradesh   11
#
#    Houses completed under PMAY as a percentage of net demand assessment for houses  \
# 0                                             100.00
# 1                                               3.32
# 2                                                NaN
# 3                                               2.48
# 4                                               0.17
#
#    Urban households living in slums (%)  \
# 0                                  0.00
# 1                                  5.41
# 2                                  3.72
# 3                                 12.04
# 4                                  1.12
#
#    Wards with 100% door to door waste collection (%)  Waste processed (%)
# 0                                             100.00                100.0
# ...

# %%
goal11.shape
# Out:
# (38, 6)

# %%
# Goal1 + Goal2 + Goal3 + Goal4 + Goal5 + Goal6 + Goal7 + Goal8 + Goal9 + Goal10 + Goal11
goal1_11 = goal1_10.append(goal11, sort=False)

# %%
goal1_11.head()
# Out:
#           States_Uts  SDG  Population living below National Poverty line (%)  \
# 0             Target    1                                              10.95
# 1              India    1                                              21.92
# 2      A & N Islands    1                                               1.00
# 3     Andhra Pradesh    1                                               9.20
# 4  Arunachal Pradesh    1                                              34.67
#
#    Households with any usual member covered by any health scheme or health insurance (%)  \
# 0                                              100.0
# 1                                               28.7
# 2                                                5.7
# 3                                               74.6
# 4                                               58.3
#
#    Persons provided employment as a percentage of persons who demanded employment under MGNREGA (%)  \
# ...

# %%
goal1_11.shape
# Out:
# (418, 54)

# %%
# Goal15
goal15 = pd.read_csv('F:/Pykih/SDG Data/Goal 15.csv')

# %%
goal15.head()
# Out:
#           States_Uts  Total land area covered under forest (%)  \
# 0             Target                                     33.00
# 1              India                                     21.54
# 2      A & N Islands                                     81.73
# 3     Andhra Pradesh                                     17.27
# 4  Arunachal Pradesh                                     79.96
#
#    Decadal change in extent of water bodies within forests from 2005 to 2015 (%)  \
# 0                                               0.00
# 1                                              18.24
# 2                                             -15.14
# 3                                              50.64
# 4                                             -33.51
#
#    Change in forest area from 2015 to 2017 (%)  \
# 0                                         0.00
# 1                                         0.21
# 2                                        -0.11
# ...

# %%
goal15.shape
# Out:
# (38, 5)

# %%
goal15.insert(1, 'SDG', 15, allow_duplicates=False)

# %%
goal15.head()
# Out:
#           States_Uts  SDG  Total land area covered under forest (%)  \
# 0             Target   15                                     33.00
# 1              India   15                                     21.54
# 2      A & N Islands   15                                     81.73
# 3     Andhra Pradesh   15                                     17.27
# 4  Arunachal Pradesh   15                                     79.96
#
#    Decadal change in extent of water bodies within forests from 2005 to 2015 (%)  \
# 0                                               0.00
# 1                                              18.24
# 2                                             -15.14
# 3                                              50.64
# 4                                             -33.51
#
#    Change in forest area from 2015 to 2017 (%)  \
# 0                                         0.00
# 1                                         0.21
# 2                                        -0.11
# ...

# %%
goal15.shape
# Out:
# (38, 6)

# %%
# Goal1 + Goal2 + Goal3 + Goal4 + Goal5 + Goal6 + Goal7 + Goal8 + Goal9 + Goal10 + Goal11 + Goal15
goal1_15 = goal1_11.append(goal15, sort=False)

# %%
goal1_15.head()
# Out:
#           States_Uts  SDG  Population living below National Poverty line (%)  \
# 0             Target    1                                              10.95
# 1              India    1                                              21.92
# 2      A & N Islands    1                                               1.00
# 3     Andhra Pradesh    1                                               9.20
# 4  Arunachal Pradesh    1                                              34.67
#
#    Households with any usual member covered by any health scheme or health insurance (%)  \
# 0                                              100.0
# 1                                               28.7
# 2                                                5.7
# 3                                               74.6
# 4                                               58.3
#
#    Persons provided employment as a percentage of persons who demanded employment under MGNREGA (%)  \
# ...

# %%
goal1_15.shape
# Out:
# (456, 58)

# %%
# Goal16
goal16 = pd.read_csv('F:/Pykih/SDG Data/Goal 16.csv')

# %%
goal16.head()
# Out:
#           States_Uts  Reported murders per 1 lakh population  \
# 0             Target                                     1.2
# 1              India                                     2.4
# 2      A & N Islands                                     2.5
# 3     Andhra Pradesh                                     2.2
# 4  Arunachal Pradesh                                     3.5
#
#    Reported cognizable crimes against children per 1 lakh population  \
# 0                                                0.0
# 1                                               24.0
# 2                                               61.4
# 3                                               11.8
# 4                                               28.3
#
#    Estimated number of courts per 10 Lakh persons  \
# 0                                           33.76
# 1                                           12.83
# 2                                           28.05
# 3                                           31.40
# ...

# %%
goal16.insert(1, 'SDG', 16, allow_duplicates=False)

# %%
goal16.shape
# Out:
# (38, 8)

# %%
# Goal1 + Goal2 + Goal3 + Goal4 + Goal5 + Goal6 + Goal7 + Goal8 + Goal9 + Goal10 + Goal11 + Goal15 + Goal16
goal1_16 = goal1_15.append(goal16, sort=False)

# %%
goal1_16.head()
# Out:
#           States_Uts  SDG  Population living below National Poverty line (%)  \
# 0             Target    1                                              10.95
# 1              India    1                                              21.92
# 2      A & N Islands    1                                               1.00
# 3     Andhra Pradesh    1                                               9.20
# 4  Arunachal Pradesh    1                                              34.67
#
#    Households with any usual member covered by any health scheme or health insurance (%)  \
# 0                                              100.0
# 1                                               28.7
# 2                                                5.7
# 3                                               74.6
# 4                                               58.3
#
#    Persons provided employment as a percentage of persons who demanded employment under MGNREGA (%)  \
# ...

# %%
goal1_16.shape
# Out:
# (494, 64)

# %%
goal1_16.to_csv('SDG India Index with goal.csv', index =False)

# %%
# convert csv to xlsx file
"""writer = pd.ExcelWriter('SDG India Index with goal.xlsx')
goal1_16.to_excel(writer, index = False)
writer.save()"""
# Out:
# "writer = pd.ExcelWriter('SDG India Index with goal.xlsx')\ngoal1_16.to_excel(writer, index = False)\nwriter.save()"
